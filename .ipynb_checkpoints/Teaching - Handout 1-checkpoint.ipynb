# %% [markdown]
# # Lesson 1 - Getting Started

# %% [markdown]
# ## Basic arithmetic

# %% [markdown]
# We can treat Python as a scientific calculator. Let's try some operations!

# %%
# Addition (+) | Run this cell to see the result
# Out:
# 11

# %%
# Subtraction (-) | Run this cell to see the result
# Out:
# 5

# %%
# Division (/) | Run this cell to see the result
# Out:
# 1.0

# %%
# Multiplication (*) | Run this cell to see the result
# Out:
# 20

# %%
# Exponentiation (**) | Run this cell to see the results
# Out:
# 25

# %% [markdown]
# ## Variables and data types

# %% [markdown]
# In Python we can assign values to different variables. This is useful when we want to do multiple things with a certain value.
# The way we assign variables is by using the equal sign =
# Let's see some examples!

# %%
# Let's say we want to store 5 and 10 as my_first_integer and my_second_integer
my_first_integer = 
my_second_integer =

# %%
# Now let's make use of addition to see the result of adding my_first_integer and my_second_integer
my_first_integer + my_second_integer
# Out:
# 15

# %% [markdown]
# Now that we know how to assign variables let's discover the different types of variables we can use in Python.

# %%
# Strings (‘’ or " ") | What we want to treat as text 
my_first_string = "This is a string"

# %%
# We can see what is stored inside of our variable by using the print function
print(my_first_string)
# Out:
# This is a string

# %%
# Integers | Numbers, already seen in the first example. Note that we can change the value of a variable.
my_first_int = 10
print(my_first_integer + my_second_integer)

# Run it and see how we changed the previously defined version of my_first_integer
# Out:
# 20

# %%
# Floats | Decimal numbers. Note that when we do operations with both integers and floats, 
# Python will prioritize floats, and thus it will return a float.

my_first_float = 
print(my_first_float)

# %%
# Now, let's actually see operations using both integers and floats
print(my_first_float + my_first_integer) #5.5 + 10

# %%
# Let's recall the example using division at the beginning. We did 5/5 and got 1.0 . Does that look like a float
# or like an integer? To check this, we can make use of the function type() which will tell us what data type our
# variable is storing.

type(5/5)

# %%
# Boolean (True or False) | They are mostly used for logical operations. Let's play around with two integers
# to see how they work

a = 20
b = 10
my_first_boolean = 20 > 10 #This boolean will tell us whether 20 is greater than 10 or not. 
my_second_boolean = 20 < 10 #This boolean will tell us whether 20 is less than 10 or not.

print(my_first_boolean)
print(my_second_boolean)

# Similarly, we can also use greater than or equal by typing >= and less than or equal by typing <=

# %%
# Boolean (True or False) | They are mostly used for logical operations. Let's play around with two integers
# to see how they work

a = 20
b = 10
my_first_boolean = 20 > 10 #This boolean will tell us whether 20 is greater than 10 or not. 
my_second_boolean = 20 < 10 #This boolean will tell us whether 20 is less than 10 or not.

print(my_first_boolean)
print(my_second_boolean)
# Out:
# True
# False

# %%
# More boolean operations
a = 10
b = 10
my_third_boolean = a == b #This boolean will tell us whether a is equal to b or not.
my_fourth_boolean = a != b #This boolean will tell us whether a is different from b or not

#Now let's print them, should we expect the results to be them same or opposite?

print(my_third_boolean)
print(my_fourth_boolean)

# %% [markdown]
# ## Data Structures

# %% [markdown]
# Now that we know the different data types that we can come across in Python, it is important to understand how Python can organize this data for us. There are five different configurations of data that you will likely come across in Python: lists, tuples, sets, dictionaries, and arrays. To define a data structure we will continue using the equal sign =, let's try it!

# %%
# A LIST groups objects of the same type. A list is always signaled by [ ]
# Using the variables "my_first_integer" and "my_second_integer" that we made earlier, let's practice making a list!

integers = [my_first_integer, my_second_integer]
print(integers)
# Out:
# [5, 10]

# %%
# A TUPLE groups objects of different types. A tuple is always signaled by ( )
# Using the variables "my_first_integer" and "my_first_string" that we made earlier, let's practice making a tuple!

my_first_tuple = (my_first_integer, my_second_integer, my_first_string, my_first_string)
print(my_first_tuple)
# Out:
# (5, 10, 'This is a string', 'This is a string')

# %%
# A SET is an unordered collection of elements with no duplicate elements.
# Using the same variables, let's see two ways to make a set!

# Using { } to signal a set
my_first_set = {my_first_integer, my_second_integer, my_first_string}
print(my_first_set)

# Using the built-in function set()
my_second_set = set((my_first_integer, my_second_integer, my_first_string))
print(my_second_set)
# Out:
# {10, 'This is a string', 5}
# {10, 'This is a string', 5}

# %%
# DICTIONARIES list unordered elements that are accessed by their position in the list, via indexing.
# This data structure is used to store data values in key:value pairs.
# A Dictionary is always signaled by {}
my_first_dict = {"my_first_integer": 5,
                "my_second_integer": 10,
                "my_first_string" : "This is a string",
                "my_first_boolean" : 20 > 10}

print(my_first_dict)

# We can also use index syntax to access the value stored in a key variable name within a dictionary.
print(my_first_dict["my_first_string"])
# Out:
# {'my_first_integer': 5, 'my_second_integer': 10, 'my_first_string': 'This is a string', 'my_first_boolean': True}
# This is a string
# 4

# %%
# An ARRAY can consist of basic values––characters, integers, and floating point numbers. It is fundamentally similar to a list
# To the best of our knowledge, Python does not have built-in arrays.
my_first_array = [my_first_integer, my_second_integer, my_first_string, my_first_boolean]

print(my_first_array)

# We can also find a value stored in a specific position in array.
print(my_first_array[2])
print(my_first_array[3])
# Out:
# [5, 10, 'This is a string', True]
# This is a string
# True

# %%
# Our last data structure is a DATAFRAME.
# A dataframe is the convenient way to display a data file for statistical data analysis.
# We can think of dataframes as a two-dimensional array.

# To create our dataframe, we must first import a library to use one of its functions.
import pandas as pd

# We create a dataframe using lists of equal length.
my_first_df = {
  "integers": [5, 10, 15],
  "booleans": [True, False, False]
}

#load data into a DataFrame object:
df = pd.DataFrame(my_first_df)

print(df)
# Out:
#    integers  booleans
# 0         5      True
# 1        10     False
# 2        15     False

# %%
# Finally, we can find the length of any of these data structures using the len() function.
# This can be important when we are trying to find the values stored in a certain position.

print(len(my_first_tuple))
print(len(my_first_dict))

# %% [markdown]
# ## Syntaxing and Style
#
# Python is CASE-SENSITIVE. "camel" and "CAMEL" are two different variables.
#
# Python uses indentations to indicate a block of code. The default indentation (when you hit Tab) is 4 spaces. Basically, codes with the same indentation belong to the same chunk.
#
# General style of naming variables: The more descriptive the better. Don't name variables using abbreviations.

# %%
#Example of case-sensitivity
variable = "First variable"
VARIABLE = "Second variable"
vArIaBlE = "Third variable"

print(variable, VARIABLE, vArIaBlE, sep = "\n", end = "\n\n")

#Example of indentation
def main():
    print("The codes below belong to the same chunk - main")
    print(1+1)
    print(2+2)
    
main()
# Out:
# First variable
# Second variable
# Third variable
#
# The codes below belong to the same chunk - main
# 2
# 4

# %% [markdown]
# ## Conditionals

# %% [markdown]
# Conditionals are very useful when we want to perform a task only when certain conditions are met. These conditions will be evaluated by using one of the data types we previously saw: conditionals.

# %% [markdown]
# <img src = "IMG_0961.jpg" style ="width:600px;height:350px"/>

# %%
if #REPLACE THIS WITH CONDITION :
    #REPLACE THIS WITH TASK

# %% [markdown]
# Now, if we want to perfom another task for the cases where the first condition is not met, we can use else

# %% [markdown]
# <img src = "IMG_0962.jpg" style ="width:400px;height:400px"/>

# %%
if #REPLACE THIS WITH FIRST CONDITION :
    #REPLACE THIS WITH FIRST TASK
    
else :
    #REPLACE THIS WITH SECOND TASK

# %% [markdown]
# If we would like to check another condition before executing else, we can use elif.

# %% [markdown]
# <img src = "IMG_0963.jpg" style ="width:600px;height:580px"/>

# %%
if #CHANGE THIS TO FIRST CONDITION:
    #CHANGE THIS TO FIRST TASK
    
elif #CHANGE THIS TO SECOND CONDITION:
    #CHANGE THIS TO SECOND TASK
    
else :
    #CHANGE THIS TO THIRD TASK

# %% [markdown]
# ## Functions
#
# When you find yourself having to do a task that requires writing the same chunk of code multiple times, it is a strong signal to make a function. Basically, a function is just a chunk of code that when you call it by explicitly typing out its name, that chunk will run.
#
# To create a funciton, you need the keyword "def" and a colon ":" to "mark" a code chunk.

# %%
# Example of a function. Note that defining the function itself doesn't run it
def square(number):
    print(number * number)

# Calling square function
square(13)
square(69)
# Out:
# 169
# 4761

# %% [markdown]
# ## Libraries
#
# A LIBRARY is a collection of prewritten code that programmers can use to accomplish a task. A way to think about libraries is that if you find yourself wanting to come up with a function to perform a task, chances are someone else already came up with a way to do it and created a library of functions. The goal of knowing and using libraries (also known as modules) is to save you time by allowing you to use other people’s work, without having to reinvent the wheel. Earlier we saw an example of how to import a library when we created our first dataframe. Let's practice importing a couple libraries we will be using in this course, and along the way we will teach you how to install libraries that do not already exist on your computer.
#
# Libraries we will introduce in this course:
# + NumPy: Operations for multidimensional arrays and linear algebra
# + SciPy: Scientific computing (algorithms, including statistical functions)
# + pandas: Python data analysis library (creation of dataframes and data manipulation)
# + matplotlib: Tools for graphics and data visualization

# %%
# Let's import pandas again to review!

import pandas
import pandas as pd

# Now for NumPy!
import numpy as np

# Again for matplotlib
import matplotlib as plt

# Note that it does not matter what you name the library as, so long as you are consistent throughout your notebook.

# %% [markdown]
# ## Exceptions
#
# One of the most frustrating things about programming is seeing errors (or a traceback in Python). It is actually one of the leading factors that makes students drop out of programming courses.
#
# But they are here to help us, so don't be afraid! In this section, we will try out best to explain to you what those exceptions are trying to tell us.

# %%
# Example of SyntaxError
def function()

#Example of ZeroDivisionError
4 / 0

#Example of NameError
variable

#Example of TypeError
13 / "a number"
# Out:
#   Input In [17]
#     def function()#:
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Keywords
#
# As we have mentioned above, there are words reserved by the developers of Python to do very specific things, and as a result, you cannot use these words as variable names: True, False, None, def, … and many more!

# %% [markdown]
# ## How to get help!
#
# When programming it is essential to know where and how to seek help. Below are a few ways that you can for help within the Jupyter Notebook interface and also in your code:
# + Use the help() function. In your code, you can type help and within the parentheses write the function that you would like to know more about.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# + You can also use a question mark. In your code, immediately after writing the name of a function, type a question mark. This will also prompt Jupyter notebook to provide you with documentation about that function.

# %%
print?

# %% [markdown]
# + Within the Jupyter Notebook webpage, you can also use the Help menu on the bar to get more information about the library you are using, Jupyter notebooks and markdown.
#
# ![Screen%20Shot%202022-07-02%20at%2010.05.49%20AM.png](attachment:Screen%20Shot%202022-07-02%20at%2010.05.49%20AM.png)

# %% [markdown]
# + Furthermore, if you are using a library that is not covered in this dropdown menu, you can visit The Python Package Index. All of the libraries we will be using in this course are included in this menu, but if you want to do any extra exploration within Python and its other libraries, feel free to use this resource.
#
# https://pypi.org/
#
# ![Screen%20Shot%202022-07-02%20at%2010.10.01%20AM.png](attachment:Screen%20Shot%202022-07-02%20at%2010.10.01%20AM.png)
